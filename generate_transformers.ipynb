# %%
use_gpu = True #@param {type:"boolean"}
if use_gpu:
  import pynvml
  pynvml.nvmlInit()
  handle = pynvml.nvmlDeviceGetHandleByIndex(0)
  device_name = pynvml.nvmlDeviceGetName(handle)
  if device_name not in [b'Tesla T4', b'Tesla P100-PCIE-16GB']:
    print('Nooooooo')
  else:
    print('Woo! You got the right kind of GPU!')
  print(device_name)
# Out:
# Woo! You got the right kind of GPU!
# b'Tesla T4'

# %%
from IPython.display import clear_output

# %%
# !git clone https://www.github.com/nvidia/apex
# %cd apex
# !python3 setup.py install
clear_output()

# %%
# !pip install nltk>=3.4
# !pip install numpy>=1.15.4
# !pip install pandas>=0.24.0
# !pip install sentencepiece>=0.1.8
# !pip install tensorflow>=1.12.0
# !pip install boto3==1.11.11
# !pip install regex==2020.1.8
# !pip install transformers==4.6.0

clear_output()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/work_gpt3/
name_model = ["m_line_512_news_descr_v2", "s_line_512_title_4_4GB", "m_line_256_title_4_4GB", "s_line_512_descr"]
clear_output()

# %%
# !python3 rss.py \
    --rss_input=test/rss_bur.txt \
    --path_out=test
    # --add_title

# %%
# # %%time

name = name_model[1]
name_t = f'{name}.rss'
name = f'checkpoints/{name}'
len_title = 32
len_descr = 128
max_len = 400
num_return = 10
k = 50 # 50-100
p = 0.95 # 0.9 - 0.95

# !python3 generate_transformers.py \
    --model_name_or_path=$name \
    --path_to_prompt=test/rss.txt \
    --path_to_save_sample=test/$name_t \
    --length $len_title \
    --temperature 0.9 \
    --k $k \
    --p $p \
    --max_input_length $max_len \
    --num_return_sequences $num_return \
    --fp16


# name = name_model[2]
# name_t = f'{name}.rss'
# name = f'checkpoints/{name}'

# !python3 generate_transformers.py \
#     --model_name_or_path=$name \
#     --path_to_prompt=test/rss.txt \
#     --path_to_save_sample=test/$name_t \
#     --length $len_title \
#     --temperature 0.9 \
#     --k $k \
#     --p $p \
#     --pruning \
#     --max_input_length $max_len \
#     --num_return_sequences $num_return \
#     --fp16


# name = name_model[0]
# name_t = f'{name}.rss'
# name = f'checkpoints/{name}'

# !python3 generate_transformers.py \
#     --model_name_or_path=$name \
#     --path_to_prompt=test/rss.txt \
#     --path_to_save_sample=test/$name_t \
#     --length $len_descr \
#     --temperature 0.9 \
#     --k $k \
#     --p $p \
#     --pruning \
#     --max_input_length $max_len \
#     --num_return_sequences $num_return \
#     --fp16


name = name_model[3]
name_t = f'{name}.rss'
name = f'checkpoints/{name}'

# !python3 generate_transformers.py \
    --model_name_or_path=$name \
    --path_to_prompt=test/rss.txt \
    --path_to_save_sample=test/$name_t \
    --length $len_descr \
    --temperature 0.9 \
    --k $k \
    --p $p \
    --max_input_length $max_len \
    --num_return_sequences $num_return \
    --fp16

# %%
# !python3 compiling_rss.py \
    --rss_input=test \
    --path_out=test \
    --len_data $num_return \
    --max_len=512 \
    --definition_of_quality \
    --fp16

# %%
# !python3 compiling_rss_1.py \
#     --rss_input=test \
#     --path_out=test \
#     --len_data $num_return \
#     --max_len 512 \
#     --definition_of_quality \
#     --fp16
