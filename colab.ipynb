# %%
use_gpu = True #@param {type:"boolean"}
if use_gpu:
  import pynvml
  pynvml.nvmlInit()
  handle = pynvml.nvmlDeviceGetHandleByIndex(0)
  device_name = pynvml.nvmlDeviceGetName(handle)
  if device_name not in [b'Tesla T4', b'Tesla P100-PCIE-16GB']:
    print('Nooooooo')
  else:
    print('Woo! You got the right kind of GPU!')
  print(device_name)
# Out:
# Nooooooo
# b'Tesla K80'

# %%
# !git clone https://github.com/MARTUSYS/gpt
# %cd gpt
# !pip install -r requirements.txt
# Out:
# Cloning into 'gpt'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 53 (delta 29), reused 39 (delta 15), pack-reused 0
# Unpacking objects: 100% (53/53), done.
# /content/gpt
# ...
#      |████████████████████████████████| 1.4MB 11.4MB/s
# ...
#      |████████████████████████████████| 1.2MB 39.4MB/s
# ...
#      |████████████████████████████████| 133kB 39.2MB/s
# ...
#      |████████████████████████████████| 696kB 35.1MB/s
# ...
#      |████████████████████████████████| 573kB 38.9MB/s
# ...
#      |████████████████████████████████| 71kB 9.1MB/s
# ...
#      |████████████████████████████████| 5.9MB 39.8MB/s
# ...
#      |████████████████████████████████| 890kB 39.6MB/s
# ...
#      |████████████████████████████████| 3.7MB 37.2MB/s
# ...
#      |████████████████████████████████| 552kB 36.4MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/"My Drive"'
directory_path = '"Colab Notebooks"/work_gpt3'
name_model = 'model/m_512' # model/gpt2_large_bbpe_v50

# %%
# !python3 generate_transformers.py \
  --model_name_or_path=$path/$directory_path/$name_model \
  --path_to_prompt=$path/$directory_path/1.txt \
  --path_to_save_sample=$path/$directory_path/sample.txt \
  --length 128 \
  --temperature 0.9 \
  --k 50 \
  --p 0.95 \
  --num_return_sequences 3
# Out:
# 2021-01-21 09:58:29.976348: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ['Во Владивостоке 25 января ясно, температура в пределах -4...-3°C', 'Во Владивостоке 25 января ясно', 'Во Владивостоке ясно', 'Во Владивостоке температура в пределах -4...-3°C', 'Ясно, температура в пределах -4...-3°C, ощущается -8°C, влажность 62%, скорость ветра 1.4 м/с.']
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# ...
